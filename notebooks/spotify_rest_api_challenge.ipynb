# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = '4220df74a56b4691925ba75e97754d3d'
client_secret = '04b1e094b6bc497d9c6ec60f157a7bd4'
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQAXLmY9xv6IVB47sxt_I2UI2wTVtlw6dkZltjXImnjTsRIK2UmrjDc5741sjOhQUPQcGB5TporZrEfySOmjvXUEQgsoOZ6eJjnbPdbPqPCdfzx7rUI',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
access_token
# Out:
# 'BQAXLmY9xv6IVB47sxt_I2UI2wTVtlw6dkZltjXImnjTsRIK2UmrjDc5741sjOhQUPQcGB5TporZrEfySOmjvXUEQgsoOZ6eJjnbPdbPqPCdfzx7rUI'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
header_info
# Out:
# {'Authorization': 'Bearer BQAXLmY9xv6IVB47sxt_I2UI2wTVtlw6dkZltjXImnjTsRIK2UmrjDc5741sjOhQUPQcGB5TporZrEfySOmjvXUEQgsoOZ6eJjnbPdbPqPCdfzx7rUI'}

# %% [markdown]
# # Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI
artist_id = '2lxX1ivRYp26soIavdG9bX'
method = '/related-artists'

full_endpoint = base_url + resource + artist_id + method
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/2lxX1ivRYp26soIavdG9bX/related-artists'

# %%
# Start building your playlist!!!

related_artists_response = requests.get(full_endpoint, headers = header_info)
related_artists_response.status_code # esto sirve para ver el código de error
# Out:
# 200

# %%
related_artists_response.headers
# Out:
# {'content-type': 'application/json; charset=utf-8', 'cache-control': 'public, max-age=7200', 'x-robots-tag': 'noindex, nofollow', 'access-control-allow-origin': '*', 'access-control-allow-headers': 'Accept, App-Platform, Authorization, Content-Type, Origin, Retry-After, Spotify-App-Version, X-Cloud-Trace-Context, client-token, content-access-token', 'access-control-allow-methods': 'GET, POST, OPTIONS, PUT, DELETE, PATCH', 'access-control-allow-credentials': 'true', 'access-control-max-age': '604800', 'content-encoding': 'gzip', 'strict-transport-security': 'max-age=31536000', 'x-content-type-options': 'nosniff', 'date': 'Fri, 03 Nov 2023 19:36:30 GMT', 'server': 'envoy', 'Via': 'HTTP/2 edgeproxy, 1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked'}

# %%
type(related_artists_response.content)
# Out:
# bytes

# %%
related_artists_json = related_artists_response.json()
len(related_artists_json['artists'])
# Out:
# 20

# %%
related_artists_json['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
[related_artists_json['artists'][i]['name'] for i in range (len(related_artists_json['artists']))]
# Out:
# ['Eric Burdon & the Animals',
#  'The Byrds',
#  'The Spencer Davis Group',
#  'Blind Faith',
#  'Small Faces',
#  'The Troggs',
#  'Derek & The Dominos',
#  'Traffic',
#  'Buffalo Springfield',
#  'Cream',
#  'Manfred Mann',
#  "The Lovin' Spoonful",
#  'Iron Butterfly',
#  'Ten Years After',
#  'Humble Pie',
#  'Jefferson Airplane',
#  'John Mayall & The Bluesbreakers',
#  'Canned Heat',
#  'Paul Revere & The Raiders',
#  'The Animals']

# %%
#Primero construimos nuestro endpoint para top tracks
artist_id = '2lxX1ivRYp26soIavdG9bX'
method = '/top-tracks'
argument = '?market=ES' #hay que tener en cuenta lo que aparece en la documentacion
full_endpoint = base_url + resource + artist_id + method + argument
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/2lxX1ivRYp26soIavdG9bX/top-tracks?market=ES'

# %%
top_track_response = requests.get(full_endpoint, headers = header_info)
top_track_response.status_code
# Out:
# 200

# %%
top_track_json = top_track_response.json()

# %%
df_tracks = pd.DataFrame(top_track_json['tracks'])[['id' ,'href', 'name', 'uri' ]]

# %%
def get_top_tracks(artist_id):
    resource = '/artists'
    method = f'/{artist_id}/top-tracks?market=ES'
    
    url = base_url + resource + method
    
    response = requests.get(url, headers = header_info).json()
    df_tracks = pd.DataFrame(top_track_json['tracks'])[['id' ,'href', 'name', 'uri']]
    df_tracks['related_id'] = artist_id
    
    return df_tracks

# %%
get_top_tracks(artist_id='3bgsNtcf5d5h9jbQbohfBK')
# Out:
#                        id                                               href  \
# 0  3HlbrnCBdrJ1NObHLMXSZh  https://api.spotify.com/v1/tracks/3HlbrnCBdrJ1...
# 1  6o21UfW2RHkzzleZGLfFpK  https://api.spotify.com/v1/tracks/6o21UfW2RHkz...
# 2  07KYQySlrmE94gaLbhvp4X  https://api.spotify.com/v1/tracks/07KYQySlrmE9...
# 3  4OjqrdD3QILzxkGwNoMk0c  https://api.spotify.com/v1/tracks/4OjqrdD3QILz...
# 4  4AgTyC3Sk2VEDjPPYtY3Q2  https://api.spotify.com/v1/tracks/4AgTyC3Sk2VE...
# 5  0hIuZ0A7mlWQvSAoqYBbRn  https://api.spotify.com/v1/tracks/0hIuZ0A7mlWQ...
# 6  2Ajtl0ro60h3VN3rD3Y1IF  https://api.spotify.com/v1/tracks/2Ajtl0ro60h3...
# 7  48fcwp3ZkLYlhk8xUL7Rib  https://api.spotify.com/v1/tracks/48fcwp3ZkLYl...
# 8  2L5Bx3LhFMr078xAVfATny  https://api.spotify.com/v1/tracks/2L5Bx3LhFMr0...
# 9  5p0hzyyos0pqfp6IAwAAYH  https://api.spotify.com/v1/tracks/5p0hzyyos0pq...
#
#                                          name  \
# 0          Heart Full of Soul - 2015 Remaster
# 1               For Your Love - 2015 Remaster
# 2   Over Under Sideways Down - The Mono Album
# 3            Shapes of Things - 2015 Remaster
# 4    The Train Kept A-Rollin' - 2015 Remaster
# 5                   I'm a Man - 2015 Remaster
# 6                 Lost Women - The Mono Album
# 7  Stroll On (From "Blow Up") - 2015 Remaster
# 8                White Summer - 2003 Remaster
# 9       Only the Black Rose - Original Stereo
#
#                                     uri              related_id
# 0  spotify:track:3HlbrnCBdrJ1NObHLMXSZh  3bgsNtcf5d5h9jbQbohfBK
# 1  spotify:track:6o21UfW2RHkzzleZGLfFpK  3bgsNtcf5d5h9jbQbohfBK
# 2  spotify:track:07KYQySlrmE94gaLbhvp4X  3bgsNtcf5d5h9jbQbohfBK
# 3  spotify:track:4OjqrdD3QILzxkGwNoMk0c  3bgsNtcf5d5h9jbQbohfBK
# 4  spotify:track:4AgTyC3Sk2VEDjPPYtY3Q2  3bgsNtcf5d5h9jbQbohfBK
# 5  spotify:track:0hIuZ0A7mlWQvSAoqYBbRn  3bgsNtcf5d5h9jbQbohfBK
# 6  spotify:track:2Ajtl0ro60h3VN3rD3Y1IF  3bgsNtcf5d5h9jbQbohfBK
# 7  spotify:track:48fcwp3ZkLYlhk8xUL7Rib  3bgsNtcf5d5h9jbQbohfBK
# 8  spotify:track:2L5Bx3LhFMr078xAVfATny  3bgsNtcf5d5h9jbQbohfBK
# 9  spotify:track:5p0hzyyos0pqfp6IAwAAYH  3bgsNtcf5d5h9jbQbohfBK

# %%
[top_track_json['tracks'][i]['name']for i in range(len(top_track_json['tracks']))]
# Out:
# ['Heart Full of Soul - 2015 Remaster',
#  'For Your Love - 2015 Remaster',
#  'Over Under Sideways Down - The Mono Album',
#  'Shapes of Things - 2015 Remaster',
#  "The Train Kept A-Rollin' - 2015 Remaster",
#  "I'm a Man - 2015 Remaster",
#  'Lost Women - The Mono Album',
#  'Stroll On (From "Blow Up") - 2015 Remaster',
#  'White Summer - 2003 Remaster',
#  'Only the Black Rose - Original Stereo']

# %%
top_track_json['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# # artist info

# %%
id_selected = '2lxX1ivRYp26soIavdG9bX'

# %%
resource = 'artists'
parameters = f'/{id_selected}'

# %%
url = base_url + resource + parameters
print(url)
# Out:
# https://api.spotify.com/v1/artists/2lxX1ivRYp26soIavdG9bX

# %%
#API call
response = requests.get(url, headers = header_info).json()

# %%
response
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2lxX1ivRYp26soIavdG9bX'},
#  'followers': {'href': None, 'total': 932816},
#  'genres': ['album rock',
#   'blues rock',
#   'british blues',
#   'british invasion',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'hard rock',
#   'psychedelic rock',
#   'rock',
#   'singer-songwriter'],
#  'href': 'https://api.spotify.com/v1/artists/2lxX1ivRYp26soIavdG9bX',
#  'id': '2lxX1ivRYp26soIavdG9bX',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb4a237d4c8a075c2afd8d7f99',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051744a237d4c8a075c2afd8d7f99',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1784a237d4c8a075c2afd8d7f99',
#    'width': 160}],
#  'name': 'The Yardbirds',
#  'popularity': 45,
#  'type': 'artist',
#  'uri': 'spotify:artist:2lxX1ivRYp26soIavdG9bX'}

# %%
dict_artist = dict((key, [response[key]]) for key in ['id', 'name', 'genres', 'popularity', 'followers'] if key in response)

# %%
dict_artist
# Out:
# {'id': ['2lxX1ivRYp26soIavdG9bX'],
#  'name': ['The Yardbirds'],
#  'genres': [['album rock',
#    'blues rock',
#    'british blues',
#    'british invasion',
#    'classic rock',
#    'country rock',
#    'folk rock',
#    'hard rock',
#    'psychedelic rock',
#    'rock',
#    'singer-songwriter']],
#  'popularity': [45],
#  'followers': [{'href': None, 'total': 932816}]}

# %%
#artist df
df_artist = pd.DataFrame(dict_artist)

# %%
df_artist
# Out:
#                        id           name  \
# 0  2lxX1ivRYp26soIavdG9bX  The Yardbirds
#
#                                               genres  popularity  \
# 0  [album rock, blues rock, british blues, britis...          45
#
#                          followers
# 0  {'href': None, 'total': 932816}

# %%
#rename columns
df_artist = df_artist.rename(columns={'id': 'artist_id',
                                     'name': 'artist_name',
                                     'genres': 'artist_genres',
                                     'popularity': 'artist_popularity',
                                     'followers': 'artist_followers'})
df_artist
# Out:
#                 artist_id    artist_name  \
# 0  2lxX1ivRYp26soIavdG9bX  The Yardbirds
#
#                                        artist_genres  artist_popularity  \
# 0  [album rock, blues rock, british blues, britis...                 45
#
#                   artist_followers
# 0  {'href': None, 'total': 932816}

# %% [markdown]
# # related artists

# %%
#build the url for the API call:
parameters = f'/{id_selected}/related-artists'

# %%
url = base_url + resource + parameters
print(url)
# Out:
# https://api.spotify.com/v1/artists/2lxX1ivRYp26soIavdG9bX/related-artists

# %%
#API call
response = requests.get(url, headers = header_info).json()

# %%
response
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70tMW5bZT3TJUa1CWtfVkq'},
#    'followers': {'href': None, 'total': 277899},
#    'genres': ['british blues',
#     'british invasion',
#     'classic rock',
#     'folk rock'],
#    'href': 'https://api.spotify.com/v1/artists/70tMW5bZT3TJUa1CWtfVkq',
#    'id': '70tMW5bZT3TJUa1CWtfVkq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c54ef4f37c08e04010201b7a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c54ef4f37c08e04010201b7a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c54ef4f37c08e04010201b7a',
#      'width': 64}],
#    'name': 'Eric Burdon & the Animals',
#    'popularity': 34,
#    'type': 'artist',
#    'uri': 'spotify:artist:70tMW5bZT3TJUa1CWtfVkq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1PCZpxHJz7WAMF8EEq8bfc'},
#    'followers': {'href': None, 'total': 955808},
#    'genres': ['album rock',
#     'beatlesque',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'cosmic american',
#     'country rock',
#     'folk',
#     'folk rock',
#     'heartland rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'soft rock'],
#    'href': 'https://api.spotify.com/v1/artists/1PCZpxHJz7WAMF8EEq8bfc',
#    'id': '1PCZpxHJz7WAMF8EEq8bfc',
#    'images': [{'height': 685,
#      'url': 'https://i.scdn.co/image/f1cf7faba3223b4be7a0734f7c5cccaa39630570',
#      'width': 1000},
#     {'height': 438,
#      'url': 'https://i.scdn.co/image/9014ce8dd793ae2c80b4463284a18c88b161dd4c',
#      'width': 640},
#     {'height': 137,
#      'url': 'https://i.scdn.co/image/386b72509c3c8eb7d180b2d051e4c4045802c8fd',
#      'width': 200},
#     {'height': 44,
#      'url': 'https://i.scdn.co/image/8799661e8b2ef6d9ed1809163a82898ef472c781',
#      'width': 64}],
#    'name': 'The Byrds',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:1PCZpxHJz7WAMF8EEq8bfc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3i9hP422d2KMjaupTzBNVS'},
#    'followers': {'href': None, 'total': 279169},
#    'genres': ['british blues', 'british invasion', 'protopunk'],
#    'href': 'https://api.spotify.com/v1/artists/3i9hP422d2KMjaupTzBNVS',
#    'id': '3i9hP422d2KMjaupTzBNVS',
#    'images': [{'height': 739,
#      'url': 'https://i.scdn.co/image/f402a6f11640da67e60e19ae7c64b472929f80ed',
#      'width': 1000},
#     {'height': 473,
#      'url': 'https://i.scdn.co/image/034e65f1b45d15436b182abc6a6123fede8a345f',
#      'width': 640},
#     {'height': 148,
#      'url': 'https://i.scdn.co/image/4246ed44ca66fc882d5d845f5c6e7cbede706ebd',
#      'width': 200},
#     {'height': 47,
#      'url': 'https://i.scdn.co/image/b7b15bceecb2c4edcfd20a6a495c03a1f4b567af',
#      'width': 64}],
#    'name': 'The Spencer Davis Group',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:3i9hP422d2KMjaupTzBNVS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5GUVj2b1lJ4DolQyHlzyaO'},
#    'followers': {'href': None, 'total': 390511},
#    'genres': ['blues',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'folk rock',
#     'mellow gold',
#     'roots rock',
#     'singer-songwriter',
#     'southern rock',
#     'supergroup'],
#    'href': 'https://api.spotify.com/v1/artists/5GUVj2b1lJ4DolQyHlzyaO',
#    'id': '5GUVj2b1lJ4DolQyHlzyaO',
#    'images': [{'height': 727,
#      'url': 'https://i.scdn.co/image/7cb47aa5aba19de14aef71b7b55bdd391a199800',
#      'width': 1000},
#     {'height': 465,
#      'url': 'https://i.scdn.co/image/4b257c080672292ddf84aa30572b49a3b1bdb12f',
#      'width': 640},
#     {'height': 145,
#      'url': 'https://i.scdn.co/image/263c07debf9ee6357de823105f422b5583b9aef0',
#      'width': 199},
#     {'height': 47,
#      'url': 'https://i.scdn.co/image/1cec97204eaf887dd8c192cdbdb40138c0a754bc',
#      'width': 64}],
#    'name': 'Blind Faith',
#    'popularity': 43,
#    'type': 'artist',
#    'uri': 'spotify:artist:5GUVj2b1lJ4DolQyHlzyaO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1YqGsKpdixxSVgpfaL2AEQ'},
#    'followers': {'href': None, 'total': 318793},
#    'genres': ['british blues', 'british invasion', 'protopunk'],
#    'href': 'https://api.spotify.com/v1/artists/1YqGsKpdixxSVgpfaL2AEQ',
#    'id': '1YqGsKpdixxSVgpfaL2AEQ',
#    'images': [{'height': 1021,
#      'url': 'https://i.scdn.co/image/c60674ffc4b94efe99f46196cb1aeaf5bb60956e',
#      'width': 1000},
#     {'height': 653,
#      'url': 'https://i.scdn.co/image/112c0df90f90668796165ba139dd622a98989205',
#      'width': 640},
#     {'height': 204,
#      'url': 'https://i.scdn.co/image/fae50e374de213c432f5e06947568af0fffe6262',
#      'width': 200},
#     {'height': 65,
#      'url': 'https://i.scdn.co/image/c4e2dedb130c47351f908c7d3bffe80e2cad1bee',
#      'width': 64}],
#    'name': 'Small Faces',
#    'popularity': 42,
#    'type': 'artist',
#    'uri': 'spotify:artist:1YqGsKpdixxSVgpfaL2AEQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/57xdnSVt4ahJCIXYLieQ25'},
#    'followers': {'href': None, 'total': 281881},
#    'genres': ['british blues', 'british invasion'],
#    'href': 'https://api.spotify.com/v1/artists/57xdnSVt4ahJCIXYLieQ25',
#    'id': '57xdnSVt4ahJCIXYLieQ25',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/be13aa2f252209f24469693dbef7050ec39d199c',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/fe9c90c71893b19ee3e997114ff736ec7c8376c5',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/c391869f006f9f04121e25192bbc72fbb6e11ec9',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/61028c03af651c2321da28ff82d1c31c078e872a',
#      'width': 64}],
#    'name': 'The Troggs',
#    'popularity': 46,
#    'type': 'artist',
#    'uri': 'spotify:artist:57xdnSVt4ahJCIXYLieQ25'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2rc78XDH9zuJP6bm78lU8Z'},
#    'followers': {'href': None, 'total': 673290},
#    'genres': ['album rock',
#     'blues',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'folk rock',
#     'hard rock',
#     'heartland rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/2rc78XDH9zuJP6bm78lU8Z',
#    'id': '2rc78XDH9zuJP6bm78lU8Z',
#    'images': [{'height': 584,
#      'url': 'https://i.scdn.co/image/cfec75171b6394ae543eb906e86e4d50cbafd9dc',
#      'width': 1000},
#     {'height': 374,
#      'url': 'https://i.scdn.co/image/aa3b048b03e1623ac90121182ee112c891874e44',
#      'width': 640},
#     {'height': 117,
#      'url': 'https://i.scdn.co/image/ce8f891b4249799af34c9735ae4a31f9c3d5170b',
#      'width': 200},
#     {'height': 37,
#      'url': 'https://i.scdn.co/image/03db779ed669aa757d1b4962d1332f8870f8b1c6',
#      'width': 63}],
#    'name': 'Derek & The Dominos',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:2rc78XDH9zuJP6bm78lU8Z'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CD77o9fbdyQFrHnUPUEsF'},
#    'followers': {'href': None, 'total': 578458},
#    'genres': ['art rock',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'folk',
#     'folk rock',
#     'heartland rock',
#     'mellow gold',
#     'progressive rock',
#     'proto-metal',
#     'psychedelic rock',
#     'roots rock',
#     'symphonic rock'],
#    'href': 'https://api.spotify.com/v1/artists/1CD77o9fbdyQFrHnUPUEsF',
#    'id': '1CD77o9fbdyQFrHnUPUEsF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe60afea4e6e1cd7c60a27cd3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e60afea4e6e1cd7c60a27cd3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e60afea4e6e1cd7c60a27cd3',
#      'width': 160}],
#    'name': 'Traffic',
#    'popularity': 46,
#    'type': 'artist',
#    'uri': 'spotify:artist:1CD77o9fbdyQFrHnUPUEsF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3eskO5m0H4yiF64vRySBjr'},
#    'followers': {'href': None, 'total': 771700},
#    'genres': ['album rock',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'folk',
#     'folk rock',
#     'heartland rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'roots rock',
#     'soft rock',
#     'southern rock'],
#    'href': 'https://api.spotify.com/v1/artists/3eskO5m0H4yiF64vRySBjr',
#    'id': '3eskO5m0H4yiF64vRySBjr',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/b701ba75981d0b9aeef036b9fab4e3c96609e364',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/52e254506bdba02418c836d1272f8de58933d7c6',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/f4ea5031036120db540cf8efdf24a8bace04f475',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/a42b8b61115ab656d136976e32cc1b67448aae60',
#      'width': 64}],
#    'name': 'Buffalo Springfield',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:3eskO5m0H4yiF64vRySBjr'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/74oJ4qxwOZvX6oSsu1DGnw'},
#    'followers': {'href': None, 'total': 2250156},
#    'genres': ['album rock',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'folk rock',
#     'hard rock',
#     'psychedelic rock',
#     'rock',
#     'singer-songwriter',
#     'supergroup'],
#    'href': 'https://api.spotify.com/v1/artists/74oJ4qxwOZvX6oSsu1DGnw',
#    'id': '74oJ4qxwOZvX6oSsu1DGnw',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/aab6a0a0e9ca2ab17460b0451e59ba507cc5802a',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/e66b5373212e507f9695921b5899f80a926b1c92',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/a4ba54e5ad0a2ef0324205130cca16df1e19c822',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/7c7f6a3fef88d1aeacef8b8a8a9d632eb606d2b1',
#      'width': 64}],
#    'name': 'Cream',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:74oJ4qxwOZvX6oSsu1DGnw'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5670CyWrIOA7702gNjsGMZ'},
#    'followers': {'href': None, 'total': 350401},
#    'genres': ['british blues',
#     'british invasion',
#     'classic rock',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/5670CyWrIOA7702gNjsGMZ',
#    'id': '5670CyWrIOA7702gNjsGMZ',
#    'images': [{'height': 935,
#      'url': 'https://i.scdn.co/image/c06b9e6723a6ec5be9ac73454ef807e3e3e1f27f',
#      'width': 1000},
#     {'height': 598,
#      'url': 'https://i.scdn.co/image/cae718dac757412d62854a504727d0af8c95f3b1',
#      'width': 640},
#     {'height': 187,
#      'url': 'https://i.scdn.co/image/9e0d557f8524dacdbfd0de0f9ef747fb937c3cb3',
#      'width': 200},
#     {'height': 60,
#      'url': 'https://i.scdn.co/image/01787f80137c8b140780c6a5f35d3165dea1eae7',
#      'width': 64}],
#    'name': 'Manfred Mann',
#    'popularity': 47,
#    'type': 'artist',
#    'uri': 'spotify:artist:5670CyWrIOA7702gNjsGMZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7CCn4PFRRRZF127jtCBAUe'},
#    'followers': {'href': None, 'total': 487485},
#    'genres': ['bubblegum pop',
#     'classic rock',
#     'country rock',
#     'folk',
#     'folk rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock-and-roll',
#     'soft rock'],
#    'href': 'https://api.spotify.com/v1/artists/7CCn4PFRRRZF127jtCBAUe',
#    'id': '7CCn4PFRRRZF127jtCBAUe',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/d0fc74cb2e10858c1b0b2436e6f14cee0944f8df',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/9cfeac22d552b1fdd4ce693ebacda71ba709543b',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/c5691f2ab0192da30ee918b9ee39d090600c9e6b',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/cd5475cade1895867fab14c8ffc479f7b523828d',
#      'width': 64}],
#    'name': "The Lovin' Spoonful",
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:7CCn4PFRRRZF127jtCBAUe'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cdvlbCYf4WoBdy89RWkNS'},
#    'followers': {'href': None, 'total': 396417},
#    'genres': ['acid rock',
#     'album rock',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'folk rock',
#     'hard rock',
#     'progressive rock',
#     'proto-metal',
#     'psychedelic rock',
#     'symphonic rock'],
#    'href': 'https://api.spotify.com/v1/artists/3cdvlbCYf4WoBdy89RWkNS',
#    'id': '3cdvlbCYf4WoBdy89RWkNS',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/ed1f30ed69dc1c5a6b7f649d2e14b06fb021c683',
#      'width': 1000},
#     {'height': 771,
#      'url': 'https://i.scdn.co/image/e8916b00606d935aadade3e0a12e45234cfcd7cb',
#      'width': 627},
#     {'height': 246,
#      'url': 'https://i.scdn.co/image/c5e8d956804e61e0026cd845206f94f55be34d9c',
#      'width': 200},
#     {'height': 79,
#      'url': 'https://i.scdn.co/image/3bd2b14da45c4ff71dc3d0e0944a2f08c3ca2fa5',
#      'width': 64}],
#    'name': 'Iron Butterfly',
#    'popularity': 40,
#    'type': 'artist',
#    'uri': 'spotify:artist:3cdvlbCYf4WoBdy89RWkNS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nkLRaWHImCvWGHdNGnhVE'},
#    'followers': {'href': None, 'total': 528710},
#    'genres': ['blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'hard rock',
#     'progressive rock',
#     'psychedelic rock'],
#    'href': 'https://api.spotify.com/v1/artists/7nkLRaWHImCvWGHdNGnhVE',
#    'id': '7nkLRaWHImCvWGHdNGnhVE',
#    'images': [{'height': 924,
#      'url': 'https://i.scdn.co/image/2c825769bc2470bf5aaf04a5991db4612298c5dd',
#      'width': 1000},
#     {'height': 591,
#      'url': 'https://i.scdn.co/image/fddb27c65d360aa7b0ff21c494f0253299678966',
#      'width': 640},
#     {'height': 185,
#      'url': 'https://i.scdn.co/image/774063020a56f8ff5bf06a02f84c31f44c39ef1d',
#      'width': 200},
#     {'height': 59,
#      'url': 'https://i.scdn.co/image/36d58380fb2bc4b43ce219432725f61f1f2d7bf3',
#      'width': 64}],
#    'name': 'Ten Years After',
#    'popularity': 49,
#    'type': 'artist',
#    'uri': 'spotify:artist:7nkLRaWHImCvWGHdNGnhVE'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2CxLP749mup3ncPrXgCnvU'},
#    'followers': {'href': None, 'total': 335960},
#    'genres': ['album rock',
#     'blues rock',
#     'british blues',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'folk rock',
#     'hard rock',
#     'proto-metal',
#     'psychedelic rock',
#     'southern rock'],
#    'href': 'https://api.spotify.com/v1/artists/2CxLP749mup3ncPrXgCnvU',
#    'id': '2CxLP749mup3ncPrXgCnvU',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/fe8c25b3f5a72047ad6a71632219a9e3ca05d2f4',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/87ed2153d64b9451450c0cbd17e776b404236f17',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/0278d69f2747b3c70fb35d76dc877e21fd4d94d7',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/890d866c2c5eaba3440a4e3b37a30ebec304fad1',
#      'width': 64}],
#    'name': 'Humble Pie',
#    'popularity': 36,
#    'type': 'artist',
#    'uri': 'spotify:artist:2CxLP749mup3ncPrXgCnvU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2qFr8w5sWUITRlzZ9kZotF'},
#    'followers': {'href': None, 'total': 1512083},
#    'genres': ['acid rock',
#     'album rock',
#     'blues rock',
#     'classic rock',
#     'folk rock',
#     'hard rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/2qFr8w5sWUITRlzZ9kZotF',
#    'id': '2qFr8w5sWUITRlzZ9kZotF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb0c739f8231961acda83a4bf8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051740c739f8231961acda83a4bf8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1780c739f8231961acda83a4bf8',
#      'width': 160}],
#    'name': 'Jefferson Airplane',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:2qFr8w5sWUITRlzZ9kZotF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ScuQMRWThcifBRIvNDFDC'},
#    'followers': {'href': None, 'total': 414054},
#    'genres': ['blues',
#     'blues rock',
#     'british blues',
#     'british invasion',
#     'electric blues',
#     'traditional blues'],
#    'href': 'https://api.spotify.com/v1/artists/2ScuQMRWThcifBRIvNDFDC',
#    'id': '2ScuQMRWThcifBRIvNDFDC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c40ff56a16cebb8f30af1f66',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c40ff56a16cebb8f30af1f66',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c40ff56a16cebb8f30af1f66',
#      'width': 64}],
#    'name': 'John Mayall & The Bluesbreakers',
#    'popularity': 43,
#    'type': 'artist',
#    'uri': 'spotify:artist:2ScuQMRWThcifBRIvNDFDC'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/27a0GiCba9K9lnkKidroFU'},
#    'followers': {'href': None, 'total': 607504},
#    'genres': ['blues',
#     'blues rock',
#     'classic rock',
#     'country rock',
#     'electric blues',
#     'folk rock',
#     'psychedelic rock',
#     'traditional blues'],
#    'href': 'https://api.spotify.com/v1/artists/27a0GiCba9K9lnkKidroFU',
#    'id': '27a0GiCba9K9lnkKidroFU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe205bb8e13cd75d79b9a6c44',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e205bb8e13cd75d79b9a6c44',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e205bb8e13cd75d79b9a6c44',
#      'width': 160}],
#    'name': 'Canned Heat',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:27a0GiCba9K9lnkKidroFU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/32HPpJAhgnGPT3V7UOggzi'},
#    'followers': {'href': None, 'total': 210012},
#    'genres': ['bubblegum pop',
#     'classic garage rock',
#     'classic rock',
#     'country rock',
#     'folk rock',
#     'mellow gold',
#     'protopunk',
#     'psychedelic rock',
#     'rock-and-roll',
#     'singer-songwriter',
#     'soft rock'],
#    'href': 'https://api.spotify.com/v1/artists/32HPpJAhgnGPT3V7UOggzi',
#    'id': '32HPpJAhgnGPT3V7UOggzi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc09bd1fa580e514ec9ada728',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c09bd1fa580e514ec9ada728',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c09bd1fa580e514ec9ada728',
#      'width': 160}],
#    'name': 'Paul Revere & The Raiders',
#    'popularity': 36,
#    'type': 'artist',
#    'uri': 'spotify:artist:32HPpJAhgnGPT3V7UOggzi'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#    'followers': {'href': None, 'total': 2300096},
#    'genres': ['album rock',
#     'british invasion',
#     'classic rock',
#     'hard rock',
#     'protopunk',
#     'psychedelic rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#    'id': '3ICflSq6ZgYAIrm2CTkfVP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb3ce1e2a99cffc7c662938b01',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051743ce1e2a99cffc7c662938b01',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1783ce1e2a99cffc7c662938b01',
#      'width': 160}],
#    'name': 'The Animals',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}]}

# %%
#build a related artist df
df_related_artists = pd.DataFrame(response['artists'])[['id', 'name', 'genres', 'popularity', 'followers']]

# %%
#rename columns
df_artist = df_artist.rename(columns={'id': 'artist_id',
                                     'name': 'artist_name',
                                     'genres': 'artist_genres',
                                     'popularity': 'artist_popularity',
                                     'followers': 'artist_followers'})

#add a column whit selected id artist
df_related_artists['artist_id'] = id_selected

#join artist and related artist to merge info
df_related_artists = pd.merge(df_related_artists, df_artist, on = 'artist_id')
df_related_artists
# Out:
#                         id                             name  \
# 0   70tMW5bZT3TJUa1CWtfVkq        Eric Burdon & the Animals
# 1   1PCZpxHJz7WAMF8EEq8bfc                        The Byrds
# 2   3i9hP422d2KMjaupTzBNVS          The Spencer Davis Group
# 3   5GUVj2b1lJ4DolQyHlzyaO                      Blind Faith
# 4   1YqGsKpdixxSVgpfaL2AEQ                      Small Faces
# 5   57xdnSVt4ahJCIXYLieQ25                       The Troggs
# 6   2rc78XDH9zuJP6bm78lU8Z              Derek & The Dominos
# 7   1CD77o9fbdyQFrHnUPUEsF                          Traffic
# 8   3eskO5m0H4yiF64vRySBjr              Buffalo Springfield
# 9   74oJ4qxwOZvX6oSsu1DGnw                            Cream
# 10  5670CyWrIOA7702gNjsGMZ                     Manfred Mann
# 11  7CCn4PFRRRZF127jtCBAUe              The Lovin' Spoonful
# 12  3cdvlbCYf4WoBdy89RWkNS                   Iron Butterfly
# 13  7nkLRaWHImCvWGHdNGnhVE                  Ten Years After
# 14  2CxLP749mup3ncPrXgCnvU                       Humble Pie
# 15  2qFr8w5sWUITRlzZ9kZotF               Jefferson Airplane
# 16  2ScuQMRWThcifBRIvNDFDC  John Mayall & The Bluesbreakers
# 17  27a0GiCba9K9lnkKidroFU                      Canned Heat
# 18  32HPpJAhgnGPT3V7UOggzi        Paul Revere & The Raiders
# 19  3ICflSq6ZgYAIrm2CTkfVP                      The Animals
#
#                                                genres  popularity  \
# 0   [british blues, british invasion, classic rock...          34
# 1   [album rock, beatlesque, blues rock, british b...          53
# 2        [british blues, british invasion, protopunk]          48
# 3   [blues, blues rock, british blues, classic roc...          43
# 4        [british blues, british invasion, protopunk]          42
# 5                   [british blues, british invasion]          46
# 6   [album rock, blues, blues rock, british blues,...          55
# 7   [art rock, blues rock, british blues, classic ...          46
# 8   [album rock, blues rock, british blues, classi...          60
# 9   [album rock, blues rock, british blues, classi...          61
# 10  [british blues, british invasion, classic rock...          47
# 11  [bubblegum pop, classic rock, country rock, fo...          55
# 12  [acid rock, album rock, blues rock, british bl...          40
# 13  [blues rock, british blues, classic rock, coun...          49
# 14  [album rock, blues rock, british blues, classi...          36
# 15  [acid rock, album rock, blues rock, classic ro...          57
# 16  [blues, blues rock, british blues, british inv...          43
# 17  [blues, blues rock, classic rock, country rock...          52
# 18  [bubblegum pop, classic garage rock, classic r...          36
# 19  [album rock, british invasion, classic rock, h...          62
#
#                            followers               artist_id    artist_name  \
# 0    {'href': None, 'total': 277899}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 1    {'href': None, 'total': 955808}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 2    {'href': None, 'total': 279169}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 3    {'href': None, 'total': 390511}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 4    {'href': None, 'total': 318793}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 5    {'href': None, 'total': 281881}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 6    {'href': None, 'total': 673290}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 7    {'href': None, 'total': 578458}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 8    {'href': None, 'total': 771700}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 9   {'href': None, 'total': 2250156}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 10   {'href': None, 'total': 350401}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 11   {'href': None, 'total': 487485}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 12   {'href': None, 'total': 396417}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 13   {'href': None, 'total': 528710}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 14   {'href': None, 'total': 335960}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 15  {'href': None, 'total': 1512083}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 16   {'href': None, 'total': 414054}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 17   {'href': None, 'total': 607504}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 18   {'href': None, 'total': 210012}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
# 19  {'href': None, 'total': 2300096}  2lxX1ivRYp26soIavdG9bX  The Yardbirds
#
#                                         artist_genres  artist_popularity  \
# 0   [album rock, blues rock, british blues, britis...                 45
# 1   [album rock, blues rock, british blues, britis...                 45
# 2   [album rock, blues rock, british blues, britis...                 45
# 3   [album rock, blues rock, british blues, britis...                 45
# 4   [album rock, blues rock, british blues, britis...                 45
# 5   [album rock, blues rock, british blues, britis...                 45
# 6   [album rock, blues rock, british blues, britis...                 45
# 7   [album rock, blues rock, british blues, britis...                 45
# 8   [album rock, blues rock, british blues, britis...                 45
# 9   [album rock, blues rock, british blues, britis...                 45
# 10  [album rock, blues rock, british blues, britis...                 45
# 11  [album rock, blues rock, british blues, britis...                 45
# 12  [album rock, blues rock, british blues, britis...                 45
# 13  [album rock, blues rock, british blues, britis...                 45
# 14  [album rock, blues rock, british blues, britis...                 45
# 15  [album rock, blues rock, british blues, britis...                 45
# 16  [album rock, blues rock, british blues, britis...                 45
# 17  [album rock, blues rock, british blues, britis...                 45
# 18  [album rock, blues rock, british blues, britis...                 45
# 19  [album rock, blues rock, british blues, britis...                 45
#
#                    artist_followers
# 0   {'href': None, 'total': 932816}
# 1   {'href': None, 'total': 932816}
# 2   {'href': None, 'total': 932816}
# 3   {'href': None, 'total': 932816}
# 4   {'href': None, 'total': 932816}
# 5   {'href': None, 'total': 932816}
# 6   {'href': None, 'total': 932816}
# 7   {'href': None, 'total': 932816}
# 8   {'href': None, 'total': 932816}
# 9   {'href': None, 'total': 932816}
# 10  {'href': None, 'total': 932816}
# 11  {'href': None, 'total': 932816}
# 12  {'href': None, 'total': 932816}
# 13  {'href': None, 'total': 932816}
# 14  {'href': None, 'total': 932816}
# 15  {'href': None, 'total': 932816}
# 16  {'href': None, 'total': 932816}
# 17  {'href': None, 'total': 932816}
# 18  {'href': None, 'total': 932816}
# 19  {'href': None, 'total': 932816}

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
